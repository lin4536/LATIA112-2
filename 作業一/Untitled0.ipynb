# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)

import os
os.chdir("/content/gdrive/My Drive//實務分析/") # 切換目錄
#!ls -l "/content/gdrive/My Drive/111oversea_APP1.csv/" # 列出目錄下的檔案
# !ls -l "111oversea_APP1.csv"
# Out:
# Mounted at /content/gdrive/
# -rw------- 1 root root 1736 Jun  1 23:44 111oversea_APP1.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
csv_file ="111oversea_APP1.csv"
df = pd.read_csv(csv_file)
# Colab 進行matplotlib繪圖時顯示繁體中文
# 下載台北思源黑體並命名taipei_sans_tc_beta.ttf，移至指定路徑
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')

continent_counts = df['洲別'].value_counts()

plt.figure(figsize=(10, 6))
continent_counts.plot(kind='bar', color=['blue', 'green', 'red', 'cyan', 'magenta'])
plt.title('各大洲國家數量統計')
plt.xlabel('大洲')
plt.ylabel('國家數量')
plt.xticks(rotation=45)
plt.show()
# Out:
# --2024-06-02 00:25:03--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 74.125.69.100, 74.125.69.101, 74.125.69.113, ...
# Connecting to drive.google.com (drive.google.com)|74.125.69.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2024-06-02 00:25:03--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.196.132, 2607:f8b0:4001:c61::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.196.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
csv_file ="111oversea_APP1.csv"
df = pd.read_csv(csv_file)
# Colab 進行matplotlib繪圖時顯示繁體中文
# 下載台北思源黑體並命名taipei_sans_tc_beta.ttf，移至指定路徑
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
continent_university_counts = df.groupby('洲別')['大學校院'].sum().reset_index()

# 绘制图表
plt.figure(figsize=(10, 6))
plt.plot(continent_university_counts['洲別'], continent_university_counts['大學校院'], marker='o')
plt.title('各洲別在大專校院的人數')
plt.xlabel('洲別')
plt.ylabel('人數')
plt.grid(True)
plt.show()
# Out:
# --2024-06-02 00:47:23--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 74.125.69.101, 74.125.69.113, 74.125.69.100, ...
# Connecting to drive.google.com (drive.google.com)|74.125.69.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2024-06-02 00:47:23--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.172.132, 2607:f8b0:4001:c61::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.172.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
csv_file ="111oversea_APP1.csv"
df = pd.read_csv(csv_file)
# Colab 進行matplotlib繪圖時顯示繁體中文
# 下載台北思源黑體並命名taipei_sans_tc_beta.ttf，移至指定路徑
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
continent_university_counts = df.groupby('洲別')['國立臺灣師範大學僑生先修部_秋'].sum().reset_index()

# 绘制图表
plt.figure(figsize=(10, 6))
plt.plot(continent_university_counts['洲別'], continent_university_counts['國立臺灣師範大學僑生先修部_秋'], marker='o')
plt.title('各洲別在國立臺灣師範大學僑生先修部的人數')
plt.xlabel('洲別')
plt.ylabel('人數')
plt.grid(True)
plt.show()
# Out:
# --2024-06-02 00:50:14--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 74.125.69.100, 74.125.69.113, 74.125.69.102, ...
# Connecting to drive.google.com (drive.google.com)|74.125.69.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2024-06-02 00:50:14--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.172.132, 2607:f8b0:4001:c61::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.172.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
csv_file ="111oversea_APP1.csv"
df = pd.read_csv(csv_file)
# Colab 進行matplotlib繪圖時顯示繁體中文
# 下載台北思源黑體並命名taipei_sans_tc_beta.ttf，移至指定路徑
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
continent_juniorhighschool_counts = df.groupby('洲別')['國中'].sum().reset_index()

# 绘制图表
plt.figure(figsize=(10, 6))
plt.plot(continent_juniorhighschool_counts['洲別'], continent_juniorhighschool_counts['國中'], marker='o')
plt.title('各洲別在國中的人數')
plt.xlabel('洲別')
plt.ylabel('人數')
plt.grid(True)
plt.show()
# Out:
# --2024-06-02 01:02:28--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 74.125.69.100, 74.125.69.139, 74.125.69.101, ...
# Connecting to drive.google.com (drive.google.com)|74.125.69.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2024-06-02 01:02:28--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.172.132, 2607:f8b0:4001:c61::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.172.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
csv_file ="111oversea_APP1.csv"
df = pd.read_csv(csv_file)
# Colab 進行matplotlib繪圖時顯示繁體中文
# 下載台北思源黑體並命名taipei_sans_tc_beta.ttf，移至指定路徑
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
continent_Elementaryschool_counts = df.groupby('洲別')['國小'].sum().reset_index()

# 绘制图表
plt.figure(figsize=(10, 6))
plt.plot(continent_Elementaryschool_counts['洲別'], continent_Elementaryschool_counts['國小'], marker='o')
plt.title('各洲別在國小的人數')
plt.xlabel('洲別')
plt.ylabel('人數')
plt.grid(True)
plt.show()
# Out:
# --2024-06-02 01:01:04--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 74.125.69.100, 74.125.69.102, 74.125.69.113, ...
# Connecting to drive.google.com (drive.google.com)|74.125.69.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2024-06-02 01:01:04--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.172.132, 2607:f8b0:4001:c61::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.172.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
csv_file ="111oversea_APP1.csv"
df = pd.read_csv(csv_file)
# Colab 進行matplotlib繪圖時顯示繁體中文
# 下載台北思源黑體並命名taipei_sans_tc_beta.ttf，移至指定路徑
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')

# 篩選出亞洲的資料
asia_df = df[df['洲別'] == '亞洲']

# 整合各國別在高級中等學校的人數
country_highschool_counts = asia_df.groupby('國別')['高級中等學校'].sum().reset_index()

# 繪製摺線圖
plt.figure(figsize=(10, 6))
plt.plot(country_highschool_counts['國別'], country_highschool_counts['高級中等學校'], marker='o')
plt.title('亞洲各國在高級中等學校的人數')
plt.xlabel('國別')
plt.ylabel('人數')
plt.xticks(rotation=90)  # 讓 x 軸標籤垂直顯示
plt.grid(True)
plt.show()
# Out:
# --2024-06-02 00:58:46--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 108.177.121.139, 108.177.121.102, 108.177.121.113, ...
# Connecting to drive.google.com (drive.google.com)|108.177.121.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2024-06-02 00:58:46--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.172.132, 2607:f8b0:4001:c61::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.172.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# ...
